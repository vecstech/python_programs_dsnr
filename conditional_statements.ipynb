# %% [markdown]
# # conditional statements in python
# 1. Python have 3 types of conditional statements
# 2. if statement
# 3. elif statement
# 4. else statement
#
# ```python
# if (logic):
#     statements
# ```
#
# ```python if, else
# if (logic):
#     statements
# else:
#     statements
# ```
#
# ```python if,elif,else
# if (logic):
#     statements
# elif (logic):
#     statements
# elif (logic):
#     statements
# elif...
#
# else:
#     statements
# ```

# %%
# write a program to check given number is even
num=int(input("please enter a number:"))
if (num%2 == 0):
    print(num,"is even number")
# Out:
# please enter a number: 121

# %%
450%2
# Out:
# 0

# %%
#write a program to find the given number is odd number or even number
n = int(input("please enter number here:"))

if (n%2 == 1):
    print(n,"is odd number")
else:
    print(n,"is even numbers")
# Out:
# please enter number here: 45655
# 45655 is odd number

# %%
# write a program to find the given number is positive or negitive or zero?
nm = int(input("please enter number here:"))
if (nm>0):
    print(nm,"is positive number")
elif(nm<0):
    print(nm,"is negitive number")
else:
    print("zero")
# Out:
# please enter number here: 0
# zero

# %%
"""
write a program to find the grades based on student marks
1. if marks in b/w 80 to 100 grade A
2. if marks in b/w 60 to 79 grade B
3. if marks in b/w 40 to 59 grade C
4. if marks in b/w 25 to 39 grade D
5. if marks in b/w 0 to 24 grade Fail
6. if marks other than above output shoub be pleae check valid marks
"""
marks=int(input("please enter student marks here:"))
if (marks>=80 and marks<=100):
    print("A grade")
elif (marks>=60 and marks<=79):
    print("B grade")
elif (marks>=40 and marks<=59):
    print("C grade")
elif (marks>=25 and marks<=39):
    print("D grade")
elif (marks>=0 and marks<=24):
    print("Fail")
else:
    print("please check valid marks")

# %%
#1. write a program to find the largest number from three numbers
#2. write a calculator program using conditional statements
#3. write a program to validate login credentials using conditional statements

# %%
n1=int(input("please enter 1st number here:"))
n2=int(input("please enter 2nd number here:"))
n3=int(input("please enter 3rd number here:"))
if (n1>=n2 and n1>=n3):
    print(n1,"is largest number")
elif(n2>=n1 and n2>=n3):
    print(n2,"is largest number")
else:
    print(n3,"is largest number")
# Out:
# please enter 1st number here: 10
# please enter 2nd number here: 10
# please enter 3rd number here: 5
# 5 is largest number

# %%
print("welcome to calculator application")
v1=int(input("enter first number here:"))
v2=int(input("enter second number here:"))
options=int(input("please select below options \n1.addition \n2.substraction \n3.multiplication \n4.division \n"))
if (options==1):
    print("addition of two number is:",v1+v2)
elif(option==2):
    print("substraction of two numbers is:",v1-v2)
elif(options==3):
    print("multiplication of two numbers is:",v1*v2)
elif(options==4):
    print("division of two numbers is:",v1/v2)
else:
    print("choose correct options")
# Out:
# welcome to calculator application
# enter first number here: 45
# enter second number here: 100
# please select below options
# 1.addition
# 2.substraction
# 3.multiplication
# 4.division
#  1
# addition of two number is: 145

# %%
username=str(input("please enter username here:"))
if (username=="shivaji123"):
    print("user name is valid")
    pwd=str(input("please enter your password here:"))
    if(pwd=="s@12345"):
        print("your password is valid")
        print(username,"welcome to python workshop")
    else:
        print("password is invalid, please check again")
else:
    print("username is invalid, please recheck")
# Out:
# please enter username here: sivaji123
# username is invalid, please recheck
